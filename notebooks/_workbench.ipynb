# %%
from openctgov.lib.helpers import protocol_feature_query

protocol_feature = protocol_feature_query()
protocol_feature
# Out:
#           _trial_id  ... _arm_count_z
# 0       NCT04834349  ...    -0.048174
# 1       NCT04837924  ...    -0.048174
# 2       NCT04838444  ...    -0.826292
# 3       NCT04831736  ...    -0.048174
# 4       NCT04837820  ...     0.729943
# ...             ...  ...          ...
# 117240  NCT00554723  ...    -0.059196
# 117241  NCT00559845  ...    -0.799786
# 117242  NCT00552136  ...    -1.540376
# 117243  NCT00556933  ...     1.421984
# 117244  NCT00558311  ...    -0.059196
#
# [117245 rows x 22 columns]

# %%
protocol_feature.to_parquet("protocol_feature_cache.parquet")
